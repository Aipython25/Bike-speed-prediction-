# %%
from sklearn.linear_model import LinearRegression
import numpy as np
X = np.array([[500], [1000], [1500], [2000], [2500]])
y = np.array([50, 100, 150, 200, 250])
model = LinearRegression( )
model.fit (X, y)
print("Price of 1800 sqft house (in $12):", model.predict([[1800]]))

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
years = np.array([[2019], [2020], [2021], [2022], [2023], [2024], [2025], [2026], [2027], [2028], [2029]])
prices = np.array([10, 20, 30, 55, 43, 34, 60, 70, 75, 80, 90])
model = LinearRegression( )
model.fit (years, prices)
future_years = np.array([[2030], [2031], [2032], [2033], [2034], [2035], [2036], [2037], [2038], [2039]])
future_prices = model.predict(future_years)
print("📊 agale 10 year ka 1000 sqft home ka anumanit rate ($ dollar me ):\n")
for year, price in zip(future_years.flatten( ), future_prices):
    print(f"year  {year}: ${price:.2f} K")

# %%
from sklearn.linear_model import LinearRegression
import numpy as np


years = np.array([[2015], [2016], [2017], [2018], [2019], [2020], [2021], [2022], [2023], [2024]])
prices = np.array([80, 85, 90, 95, 100, 110, 120, 130, 140, 150])  # ₹1000 में


model = LinearRegression()
model.fit(years, prices)


future_years = np.array([[2025], [2026], [2027], [2028], [2029], [2030], [2031], [2032], [2033], [2034], [2035]])

future_prices = model.predict(future_years)


print("📊 अगले 10 साल में 1000 sqft घर का अनुमानित दाम (₹ हजार में):\n")
for year, price in zip(future_years.flatten(), future_prices):
    print(f"Year {year}: ₹{price:.2f}K")
